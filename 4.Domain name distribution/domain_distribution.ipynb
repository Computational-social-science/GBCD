# %%
import json
import re

def extract_substring(url):
    pattern = r'://(.*?)/'
    match = re.search(pattern, url)
    if match:
        return match.group(1)
    else:
        return None
    
path_file = '/home/qiuyang/workplace/swift/examples/pytorch/llm/my_data/data/c4_data_duiqi/total_data_v1.0.json'

i = 0

# 创建一个空字典
url_dict = {}

def add_or_update_key(key):
    # 如果键不存在，则设置值为0
    if key not in url_dict:
        url_dict[key] = 1
    else:
        # 如果键存在，则值加1
        url_dict[key] += 1
total = 0
with open(path_file, 'r') as input_file:
    # 逐行读取文件内容
    for line in input_file:
        i = i + 1
        # 解析JSON数据
        data = json.loads(line)

        url = data['url']

        wangzhi = extract_substring(url)
        if wangzhi != None:
            add_or_update_key(wangzhi)
        else:
            print(url)
# print(total)
# Out:
# https://danettinger.com
# https://lankan.org
# https://rhchospitality.com
# http://www.ianpottsartist.com
# http://jadebwalsh.blogspot.com
# https://www.floridarecorder.com
# http://www.art-by-brennan.com
# https://egypt-museum.com
# https://www.carlisleschesapeake.com
# http://dokument.org?lang=en
# http://www.art-by-brennan.com
# https://egypt-museum.com
# https://www.carlisleschesapeake.com

# %%
# 创建新的字典来存储更新后的键和值
new_url_dict = {}

# 遍历原字典中的每个键和值
for key, value in url_dict.items():
    # 检查键是否以'www.'开头
    if key.startswith('www.'):
        # 去掉'www.'部分
        new_key = key.replace('www.', '', 1)
    else:
        new_key = key
    # 将新键和值添加到新字典中
    new_url_dict[new_key] = value


# 计算字典中键的数量
key_count = len(new_url_dict)
print(key_count)
# 计算字典中所有值的总和
value_sum = sum(new_url_dict.values())
print(value_sum)

# 按值从大到小排序字典，并提取前100个元素
top_100_urls = dict(sorted(new_url_dict.items(), key=lambda item: item[1], reverse=True)[:1000])
# top_100_urls['reuters.com'] = 97632
# 打印前100个元素
for url, value in top_100_urls.items():
    
    print(f"{url}: {value}")
    # print(url)
# Out:
# 359093
# 960764
# reuters.com: 148623
# cnbc.com: 42599
# nytimes.com: 33319
# cnn.com: 21239
# thehill.com: 17483
# vice.com: 8903
# people.com: 8294
# techcrunch.com: 7616
# mashable.com: 5896
# businessinsider.com: 5770
# axios.com: 4543
# politico.com: 4072
# refinery29.com: 3715
# theverge.com: 3652
# economist.com: 3605
# buzzfeednews.com: 3230
# vox.com: 3142
# foxnews.com: 2959
# news.vice.com: 2384
# hyperallergic.com: 2285
# gizmodo.com: 2029
# tmz.com: 1649
# wired.com: 1403
# newrepublic.com: 873
# en.wikipedia.org: 679
# aljazeera.com: 562
# theguardian.com: 551
# washingtonpost.com: 483
# newyorker.com: 446
# rt.com: 429
# latimes.com: 348
# straitstimes.com: 346
# alibaba.com: 338
# ibtimes.co.uk: 311
# forbes.com: 301
# yatra.com: 295
# uk.reuters.com: 292
# countrycallingcodes.com: 290
# monfrague.online: 289
# marketwired.com: 287
# telegraph.co.uk: 287
# dailymail.co.uk: 265
# en.m.wikipedia.org: 257
# huffpost.com: 253
# voanews.com: 252
# rbth.com: 252
# ...

# %%
# 非洲国家相关域名关键字列表
africa_keywords = [
    'africa', 'southafrica', 'kenya', 'nigeria', 'ghana', 'ethiopia', 'tanzania', 'uganda', 
    'rwanda', 'zimbabwe', 'botswana', 'namibia', 'sudan', 'egypt', 'libya', 'morocco', 
    'tunisia', 'algeria', 'ivorycoast', 'senegal', 'angola', 'cameroon', 'mozambique', 
    'malawi', 'zambia', 'somalia', 'chad', 'niger', 'mali', 'burkinafaso', 'benin', 
    'mauritania', 'sierra', 'leone', 'liberia', 'gabon', 'guinea', 'congo', 'djibouti', 
    'swaziland', 'comoros', 'capeverde', 'gambia', 'lesotho', 'burundi', 'seychelles', 
    'eritrea', 'africanews', 'dailymaverick', 'news24', 'thecitizen', 'allafrica', 
    'standardmedia', 'nation', 'bbcafrica', 'voaafrica', 'cnnafrica', 'reutersafrica', 
    'guardianafrica'
]

# 识别与非洲国家相关的域名并保存到新字典
africa_url_dict = {key: value for key, value in new_url_dict.items() if any(keyword in key for keyword in africa_keywords)}

# 按值从大到小排序
sorted_africa_url_dict = dict(sorted(africa_url_dict.items(), key=lambda item: item[1], reverse=True))

# 打印新的字典
for key, value in sorted_africa_url_dict.items():
    print(f'Key: {key}, Value: {value}')
# Out:
# Key: thenational.ae, Value: 140
# Key: israelnationalnews.com, Value: 121
# Key: allafrica.com, Value: 86
# Key: thenation.com, Value: 76
# Key: thesouthafrican.com, Value: 75
# Key: modernghana.com, Value: 67
# Key: nationmultimedia.com, Value: 61
# Key: moroccoworldnews.com, Value: 52
# Key: nation.com.pk, Value: 51
# Key: soranews24.com, Value: 46
# Key: nationalpost.com, Value: 45
# Key: globalnation.inquirer.net, Value: 45
# Key: blog.nationalgeographic.org, Value: 45
# Key: nationalgeographic.com, Value: 44
# Key: thenigerianvoice.com, Value: 42
# Key: africanadvice.com, Value: 42
# Key: thenationonlineng.net, Value: 40
# Key: africanews.com, Value: 39
# Key: news24online.com, Value: 37
# Key: expertafrica.com, Value: 34
# Key: egyptianstreets.com, Value: 33
# Key: egypttoday.com, Value: 31
# Key: nationalinterest.org, Value: 29
# Key: liberianobserver.com, Value: 29
# Key: internationalliving.com, Value: 28
# Key: nation.co.ke, Value: 27
# Key: news24.com, Value: 27
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# # 提取键和值
# urls = list(top_100_urls.keys())
# values = list(top_100_urls.values())

# value_sum = sum(top_100_urls.values())
# print(value_sum)

# # 创建横向的柱形图
# fig, ax = plt.subplots(figsize=(12, 8))
# ax.barh(urls, values, color='skyblue')

# # 添加标题和标签
# ax.set_title('Top 30 URLs Distribution')
# ax.set_xlabel('Values')
# ax.set_ylabel('URLs')

# # 反转Y轴，这样值最大的在上面
# ax.invert_yaxis()

# # 显示图形
# plt.show()
# 提取键和值
urls = list(top_100_urls.keys())
values = list(top_100_urls.values())

value_sum = sum(top_100_urls.values())
print(value_sum)

# 将值转换为以10为底的对数值
log_values = np.log10(values)

# 创建横向的柱形图
fig, ax = plt.subplots(figsize=(12, 8))
ax.barh(urls, log_values, color='skyblue')

# 设置 x 轴为指数刻度
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(x)}}}$'))

# 添加标题和标签
ax.set_title('Top 30 URLs Distribution')
ax.set_xlabel('Log Values (Base 10)')
ax.set_ylabel('URLs')

# 反转Y轴，这样值最大的在上面
ax.invert_yaxis()

# 显示图形
plt.show()
# Out:
# 348008

# %%
print(urls)
# Out:
# ['reuters.com', 'cnbc.com', 'nytimes.com', 'cnn.com', 'thehill.com', 'vice.com', 'people.com', 'techcrunch.com', 'mashable.com', 'businessinsider.com', 'axios.com', 'politico.com', 'refinery29.com', 'theverge.com', 'economist.com', 'buzzfeednews.com', 'vox.com', 'foxnews.com', 'news.vice.com', 'hyperallergic.com', 'gizmodo.com', 'tmz.com', 'wired.com', 'newrepublic.com', 'en.wikipedia.org', 'aljazeera.com', 'theguardian.com', 'washingtonpost.com', 'newyorker.com', 'rt.com', 'latimes.com', 'straitstimes.com', 'alibaba.com', 'ibtimes.co.uk', 'forbes.com', 'yatra.com', 'uk.reuters.com', 'countrycallingcodes.com', 'monfrague.online', 'marketwired.com', 'telegraph.co.uk', 'dailymail.co.uk', 'en.m.wikipedia.org', 'huffpost.com', 'voanews.com', 'rbth.com', 'express.co.uk', 'sputniknews.com', 'irishtimes.com', 'prweb.com']

# %%
print(len(urls))
print(len(values))
# Out:
# 50
# 50

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from scipy import stats
import statistics
from matplotlib.patches import FancyArrow
from collections import Counter
import json

top_country = urls
top_country_count = values

# 绘图
fig, ax = plt.subplots(figsize=(5, 8))
# 反转 y 轴
ax.invert_yaxis()
# 去除上方和右侧的空白
ax.margins(0)

plt.xscale('log')
plt.barh(top_country, top_country_count, height=0.8, color='#7da1db')

plt.ylabel('Urls', fontsize=12)
plt.xlabel('Data count', fontsize=12)
# 设置 x 轴刻度字体大小
ax.tick_params(axis='x', labelsize=8)
# 设置 y 轴刻度字体大小
ax.tick_params(axis='y', labelsize=8)
# plt.xticks([2000, 6000, 10000])
# 设置 x/y轴的范围
plt.xlim(10**(np.log10(np.min(top_country_count))*0.95), 10**(np.log10(np.max(top_country_count))*1.05))
plt.ylim(50, -1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 import matplotlib.pyplot as plt
#       4 from matplotlib import rcParams
# ----> 5 import seaborn as sns
#       6 from scipy import stats
#       7 import statistics
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import numpy as np
import matplotlib.pyplot as plt

# 示例数据
top_country = ['url' + str(i) for i in range(1, 51)]
top_country_count = np.random.randint(10, 1000, size=50)

# 定义分组
group_size = 5
group_labels = ['Group ' + str(i + 1) for i in range(10)]

# 生成分组索引和新的y轴标签
new_top_country = []
new_top_country_count = []
new_yticks = []

for i, group_label in enumerate(group_labels):
    start_idx = i * group_size
    end_idx = start_idx + group_size
    new_top_country.append(group_label)
    new_top_country.extend(top_country[start_idx:end_idx])
    new_top_country_count.append(0)  # 分组标签的条形高度设为0
    new_top_country_count.extend(top_country_count[start_idx:end_idx])
    new_yticks.append((start_idx + end_idx) / 2)  # 分组标签的中间位置
    new_yticks.extend([0] * group_size)  # 原始条形标签的索引

# 绘图
fig, ax = plt.subplots(figsize=(10, 8))

# 反转 y 轴
ax.invert_yaxis()

# 去除上方和右侧的空白
ax.margins(0)

plt.xscale('log')
bars = plt.barh(range(len(new_top_country)), new_top_country_count, height=0.8, color='#7da1db')

plt.ylabel('Urls', fontsize=12)
plt.xlabel('Data count', fontsize=12)

# 设置 x 轴刻度字体大小
ax.tick_params(axis='x', labelsize=8)

# 设置 y 轴刻度字体大小
ax.tick_params(axis='y', labelsize=8)

# 设置 x/y轴的范围
plt.xlim(10**(np.log10(np.min(top_country_count)) - 0.95), 10**(np.log10(np.max(top_country_count)) * 1.05))

# 在条形图上绘制文本
for i, (bar, label) in enumerate(zip(bars, new_top_country)):
    if new_top_country_count[i] > 0:  # 只在非分组标签上绘制文本
        plt.text(bar.get_width() + 5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=8)

# 设置 y 轴标签
ax.set_yticks(new_yticks)
ax.set_yticklabels(new_top_country)

plt.show()

# %%
def rearrange_list(elements, new_positions):
    # 创建一个与原列表相同长度的空列表
    rearranged = [None] * len(elements)
    
    # 根据新位置列表将元素放置到新位置
    for i, new_pos in enumerate(new_positions):
        rearranged[new_pos] = elements[i]
    
    return rearranged

# 设置字体
plt.rcParams['axes.unicode_minus'] = False
# plt.rcParams['font.family'] = 'Microsoft Yahei'
plt.rcParams['font.family'] = 'Times New Roman'


def plotSubpanelA(ax):
    index_num = [1,2,0,3,5,4,6]

    member = [u'Asia', u'Africa', u'North America', u'South America'
            ,u'Antarctica',u'Europe',u'Oceania']
    member = rearrange_list(member,index_num)
    #亚洲，非洲，北美，南美，南极洲，欧洲，大洋洲
    domain_1 = [346, 562, 148623, 332, 163, 311, 49]  
    domain_2 = [338, 118, 42599, 202, 106, 287, 38] 
    domain_3 = [295, 102, 33319, 178, 78, 33, 37]  
    domain_4 = [199, 86, 21239,  143, 75, 33, 36]
    domain_5 = [94, 171, 17483, 273, 67, 33, 122]

    domain_1 = rearrange_list(domain_1,index_num)
    domain_2 = rearrange_list(domain_2,index_num)
    domain_3 = rearrange_list(domain_3,index_num)
    domain_4 = rearrange_list(domain_4,index_num)


    colors= ['#9acaa6', '#83bd93', '#6db182', '#5aa673', '#449a61', '#339054', '#1b8340']
    colors = colors[::-1]

    # 自定义标签
    labels_1 = ['straitstimes.com', 'aljazeera.com', 'reuters.com', 'bbc.co','antarctica.gov','ibtimes.co.uk','news.com.au']
    labels_2 = ['alibaba.com', 'mg.co.za', 'cnbc.com', 'eltiempo.com','iceheadshop.org','telegraph.co.uk','skyscanner.com.au']
    labels_3 = ['yatra.com', 'naij.com', 'nytimes.com', 'infonegocios.com.ar','budapest.climatemps.com','dailymail.co.uk','sbs.com.au']
    labels_4 = ['hindustantimes.com', 'allafrica.com', 'cnn.com', 'thefader.com','globalvoices.org','irishtimes.com','9news.com.au']
    labels_5 = ['japantimes.co.jp', 'theafricareport.com', 'thehill.com', 'larepublica.pe','winnipeg.climatemps.com','sputniknews.com','nzherald.co.nz']

    labels_1 = rearrange_list(labels_1,index_num)
    labels_2 = rearrange_list(labels_2,index_num)
    labels_3 = rearrange_list(labels_3,index_num)
    labels_4 = rearrange_list(labels_4,index_num)

    bar_width = 0.2  # 设置分组条形的宽度

    ax.margins(0.02)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color=colors, alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color=colors, alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color=colors, alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color=colors, alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
    fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member,fontdict=fontdict1)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 1e6)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


def plotSubpanelB(ax):

    index_num = [2,6,5,1,3,0,4]
    member = [u'Culture', u'Sport', u'Military', u'Policy'
            ,u'Family',u'Economiscs',u'Medicine']
    member = rearrange_list(member,index_num)
    #文化 体育 战争 政策 家庭 经济 医疗
    domain_1 = [33319, 159, 274, 21239, 8294, 42599, 1249]  
    domain_2 = [551, 62, 105, 17483, 178, 5770, 145] 
    domain_3 = [483, 56, 84,  4072, 80, 58, 120]  
    domain_4 = [199, 53, 61,  2959, 42, 28, 49]
    domain_5 = [446, 46, 48,  123, 41, 301, 45]

    domain_1 = rearrange_list(domain_1,index_num)
    domain_2 = rearrange_list(domain_2,index_num)
    domain_3 = rearrange_list(domain_3,index_num)
    domain_4 = rearrange_list(domain_4,index_num)

    colors2= ['#9acaa6', '#83bd93', '#6db182', '#5aa673', '#449a61', '#339054', '#1b8340']
    colors2= colors2[::-1]

    # 自定义标签
    labels_1 = ['nytimes.com', 'si.com', 'defenseone.com','cnn.com', 'people.com','cnbc.com','health.economictimes.indiatimes.com']
    labels_2 = ['theguardian.com','espn.com', 'defense.gov', 'thehill.com','betterbatt.com.au','businessinsider.com','ncbi.nlm.nih.gov']
    labels_3 = ['washingtonpost.com', 'nhl.com', 'military.com', 'politico.com','absolutelypsychic.com','wsj.com','canadiandiscountdrugs.net']
    labels_4 = ['hindustantimes.com', 'socceroos.com.au', 'nationmultimedia.com','foxnews.com', 'dignitymemorial.com','bloomberg.com','medgadget.com']
    labels_5 = ['newyorker.com', 'teamusa.org', 'globalsecurity.org', 'nbcnews.com','justgiving.com','forbes.com','pubfacts.com']
    bar_width = 0.2  # 设置分组条形的宽度

    labels_1 = rearrange_list(labels_1,index_num)
    labels_2 = rearrange_list(labels_2,index_num)
    labels_3 = rearrange_list(labels_3,index_num)
    labels_4 = rearrange_list(labels_4,index_num)

    ax.margins(0.02)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color=colors2, alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color=colors2, alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color=colors2, alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color=colors2, alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
    fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member,fontdict=fontdict1)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 800000)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


# 删除边框和标签
def delBorder(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])

# %%
#中文的
import matplotlib.font_manager as fm
# fm.FontProperties(fname='C:/Windows/Fonts/SimHei.ttf')  # 注册SimHei字体
import matplotlib as mpl
import matplotlib.font_manager as fm
fm.fontManager.addfont('/home/qiuyang/workplace/world_map_drawing/Geographical heterogeneity/Geomap/SimHei.ttf')
fm.fontManager.addfont('/home/qiuyang/workplace/world_map_drawing/Geographical heterogeneity/Geomap/bokeh-app/data/font/times.ttf')
def rearrange_list(elements, new_positions):
    # 创建一个与原列表相同长度的空列表
    rearranged = [None] * len(elements)
    
    # 根据新位置列表将元素放置到新位置
    for i, new_pos in enumerate(new_positions):
        rearranged[new_pos] = elements[i]
    
    return rearranged

# 设置字体
# plt.rcParams['font.family'] = 'Microsoft Yahei'
# plt.rcParams['font.family'] = 'Times New Roman'

# plt.rcParams['font.family'] = 'SimHei'
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False 
def plotSubpanelA(ax):
    index_num = [1,2,0,3,5,4,6]

    member = ['亚洲', '非洲', '北美洲', '南美洲'
            ,'南极洲','欧洲','大洋洲']
    member = rearrange_list(member,index_num)
    #亚洲，非洲，北美，南美，南极洲，欧洲，大洋洲
    domain_1 = [346, 562, 148623, 332, 163, 311, 49]  
    domain_2 = [338, 118, 42599, 202, 106, 287, 38] 
    domain_3 = [295, 102, 33319, 178, 78, 33, 37]  
    domain_4 = [199, 86, 21239,  143, 75, 33, 36]
    domain_5 = [94, 171, 17483, 273, 67, 33, 122]

    domain_1 = rearrange_list(domain_1,index_num)
    domain_2 = rearrange_list(domain_2,index_num)
    domain_3 = rearrange_list(domain_3,index_num)
    domain_4 = rearrange_list(domain_4,index_num)


    colors= ['#9acaa6', '#83bd93', '#6db182', '#5aa673', '#449a61', '#339054', '#1b8340']
    colors = colors[::-1]

    # 自定义标签
    labels_1 = ['straitstimes.com', 'aljazeera.com', 'reuters', 'bbc.co','antarctica.gov','ibtimes.co.uk','news.com.au']
    labels_2 = ['alibaba.com', 'mg.co.za', 'cnbc.com', 'eltiempo.com','iceheadshop.org','telegraph.co.uk','skyscanner.com.au']
    labels_3 = ['yatra.com', 'naij.com', 'nytimes.com', 'infonegocios.com.ar','budapest.climatemps.com','dailymail.co.uk','sbs.com.au']
    labels_4 = ['hindustantimes.com', 'allafrica.com', 'cnn.com', 'thefader.com','globalvoices.org','irishtimes.com','9news.com.au']
    labels_5 = ['japantimes.co.jp', 'theafricareport.com', 'thehill.com', 'larepublica.pe','winnipeg.climatemps.com','sputniknews.com','nzherald.co.nz']

    labels_1 = rearrange_list(labels_1,index_num)
    labels_2 = rearrange_list(labels_2,index_num)
    labels_3 = rearrange_list(labels_3,index_num)
    labels_4 = rearrange_list(labels_4,index_num)

    bar_width = 0.2  # 设置分组条形的宽度

    ax.margins(0.02)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color=colors, alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color=colors, alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color=colors, alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color=colors, alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'fontsize': 15}
    fontdict3 = {'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 1e6)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


def plotSubpanelB(ax):

    index_num = [2,6,5,1,3,0,4]
    member = [u'文化', u'体育', u'军事', u'政治'
            ,u'家庭',u'经济',u'医疗']
    member = rearrange_list(member,index_num)
    #文化 体育 战争 政策 家庭 经济 医疗
    domain_1 = [33319, 159, 274, 21239, 8294, 42599, 1249]  
    domain_2 = [551, 62, 105, 17483, 178, 5770, 145] 
    domain_3 = [483, 56, 84,  4072, 80, 58, 120]  
    domain_4 = [199, 53, 61,  2959, 42, 28, 49]
    domain_5 = [446, 46, 48,  123, 41, 301, 45]

    domain_1 = rearrange_list(domain_1,index_num)
    domain_2 = rearrange_list(domain_2,index_num)
    domain_3 = rearrange_list(domain_3,index_num)
    domain_4 = rearrange_list(domain_4,index_num)

    colors2= ['#9acaa6', '#83bd93', '#6db182', '#5aa673', '#449a61', '#339054', '#1b8340']
    colors2= colors2[::-1]

    # 自定义标签
    labels_1 = ['nytimes.com', 'si.com', 'defenseone.com','cnn.com', 'people.com','cnbc.com','health.indiatimes.com']
    labels_2 = ['theguardian.com','espn.com', 'defense.gov', 'thehill.com','betterbatt.com.au','businessinsider.com','ncbi.nlm.nih.gov']
    labels_3 = ['washingtonpost.com', 'nhl.com', 'military.com', 'politico.com','absolutelypsychic.com','wsj.com','canadiandiscountdrugs.net']
    labels_4 = ['hindustantimes.com', 'socceroos.com.au', 'nationmultimedia.com','foxnews.com', 'dignitymemorial.com','bloomberg.com','medgadget.com']
    labels_5 = ['newyorker.com', 'teamusa.org', 'globalsecurity.org', 'nbcnews.com','justgiving.com','forbes.com','pubfacts.com']
    bar_width = 0.2  # 设置分组条形的宽度

    labels_1 = rearrange_list(labels_1,index_num)
    labels_2 = rearrange_list(labels_2,index_num)
    labels_3 = rearrange_list(labels_3,index_num)
    labels_4 = rearrange_list(labels_4,index_num)

    ax.margins(0.02)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color=colors2, alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color=colors2, alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color=colors2, alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color=colors2, alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'fontsize': 15}
    fontdict3 = {'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member,fontdict=fontdict1)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 800000)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


# 删除边框和标签
def delBorder(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])

# %%
domain_1 = [346, 562, 148623, 332, 163, 311, 49]  
domain_2 = [338, 118, 42599, 202, 106, 287, 38] 
domain_3 = [295, 102, 33319, 178, 78, 33, 37]  
domain_4 = [199, 86, 21239,  143, 75, 33, 36]

result_sum = []
for i in range(0,7):
    sum = domain_1[i]+domain_2[i]+domain_3[i]+domain_4[i]
    result_sum.append(sum)

print(result_sum)

index_num = [1,2,0,3,5,4,6]
# Out:
# [1178, 868, 245780, 855, 422, 664, 160]

# %%
# 设置字体
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
# plt.rcParams['font.family'] = 'Microsoft Yahei'
plt.rcParams['font.family'] = 'Times New Roman'


def plotSubpanelA(ax):
    member = [u'Asia', u'Africa', u'North America', u'South America'
            ,u'Antarctica',u'Europe',u'Oceania']
    #亚洲，非洲，北美，南美，南极洲，欧洲，大洋洲
    domain_1 = [346, 562, 148623, 332, 8903, 311, 37]  
    domain_2 = [338, 118, 42599, 143, 106, 287, 38] 
    domain_3 = [295, 86, 33319,  178, 78, 33, 49]  
    domain_4 = [199, 102, 21239,  202, 75, 33, 36]
    domain_5 = [94, 171, 17483, 273, 67, 33, 122]

    # 自定义标签
    labels_1 = ['straitstimes.com', 'aljazeera.com', 'reuters.com', 'bbc.co','vice.com','ibtimes.co.uk','sbs.com.au']
    labels_2 = ['alibaba.com', 'mg.co.za', 'cnbc.com', 'thefader.com','iceheadshop.org','telegraph.co.uk','skyscanner.com.au']
    labels_3 = ['yatra.com', 'allafrica.com', 'nytimes.com', 'infonegocios.com.ar','budapest.climatemps.com','dailymail.co.uk','news.com.au']
    labels_4 = ['hindustantimes.com', 'naij.com', 'cnn.com', 'eltiempo.com','globalvoices.org','irishtimes.com','9news.com.au']
    labels_5 = ['japantimes.co.jp', 'theafricareport.com', 'thehill.com', 'larepublica.pe','winnipeg.climatemps.com','sputniknews.com','nzherald.co.nz']
    bar_width = 0.2  # 设置分组条形的宽度

    ax.margins(0)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color='#CD5257', alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color='#F2BA2F', alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color='#2673EF', alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color='#95BE54', alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
    fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member,fontdict=fontdict1)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 1e6)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


def plotSubpanelB(ax):
    member = [u'Culture', u'Sport', u'Military', u'Policy'
            ,u'Family',u'Economiscs',u'Medicine']
    #文化 体育 战争 政策 家庭 经济 医疗
    domain_1 = [33319, 159, 84, 17483, 8294, 42599, 120]  
    domain_2 = [199, 62, 48, 4072, 178, 28, 49] 
    domain_3 = [551, 56, 105,  2959, 80, 58, 1249]  
    domain_4 = [483, 53, 61,  21239, 42, 5770, 145]
    domain_5 = [446, 46, 274, 123, 41, 301, 45]


    # 自定义标签
    labels_1 = ['nytimes.com', 'si.com', 'military.com', 'thehill.com','people.com','cnbc.com','ncbi.nlm.nih.gov']
    labels_2 = ['hindustantimes.com', 'espn.com', 'globalsecurity.org', 'politico.com','betterbatt.com.au','bloomberg.com','medgadget.com']
    labels_3 = ['theguardian.com', 'nhl.com', 'defense.gov', 'foxnews.com','absolutelypsychic.com','wsj.com','canadiandiscountdrugs.net']
    labels_4 = ['washingtonpost.com', 'socceroos.com.au', 'nationmultimedia.com', 'cnn.com','dignitymemorial.com','businessinsider.com','health.economictimes.indiatimes.com']
    labels_5 = ['newyorker.com', 'teamusa.org', 'defenseone.com', 'nbcnews.com','justgiving.com','forbes.com','pubfacts.com']
    bar_width = 0.2  # 设置分组条形的宽度

    ax.margins(0)

    # 绘图
    bars_1 = ax.barh(np.arange(7), domain_1,  height=bar_width, align='center', color='#CD5257', alpha=0.7)
    bars_2 = ax.barh(np.arange(7) + bar_width, domain_2,  color='#F2BA2F', alpha=0.7, height=bar_width)
    bars_3 = ax.barh(np.arange(7) + bar_width * 2, domain_3, color='#2673EF', alpha=0.7, height=bar_width)
    bars_4 = ax.barh(np.arange(7) + bar_width * 3, domain_4,  color='#95BE54', alpha=0.7, height=bar_width)
    # bars_5 = ax.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


    fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
    fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
    # 添加X轴标签
    # ax.set_xlabel('Count',fontdict=fontdict3, fontsize=16)
    # 添加y轴标签
    # ax.set_ylabel('Continent Domain', fontdict=fontdict3, fontsize=16)
    # 添加刻度标签
    ax.set_yticks(np.arange(7) + bar_width*1.25, member,fontdict=fontdict1)
    ax.set_xscale('log')

    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # 设置 x 轴范围
    ax.set_xlim(1, 800000)  # 将上限设置为 160000

    # 在条形的顶端加上自定义标签
    fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
    for bars, labels in zip([bars_1, bars_2, bars_3,bars_4], [labels_1, labels_2, labels_3,labels_4]):
        for bar, label in zip(bars, labels):
            width = bar.get_width()
            ax.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontsize=10)


# 删除边框和标签
def delBorder(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
fm.fontManager.addfont('/home/qiuyang/workplace/world_map_drawing/Geographical heterogeneity/Geomap/bokeh-app/data/font/times.ttf')
plt.rcParams['figure.dpi'] = 100

fig, axs = plt.subplots(figsize=(14, 5))  # 调整图形大小

# 创建子图 A B
inner_grids_A = axs.get_subplotspec().subgridspec(1, 2)
axs_A1 = fig.add_subplot(inner_grids_A[0, 0])
axs_A2 = fig.add_subplot(inner_grids_A[0, 1])
axAs = [axs_A1, axs_A2]
delBorder(axs)


plotSubpanelA(axAs[0])
plotSubpanelB(axAs[1])

# 添加X轴标签
axs_A1.set_xlabel('数量', fontsize=20, labelpad=30)
axs_A1.xaxis.set_label_coords(0.5, -0.1)  # (x, y) 坐标分别控制 x 轴和 y 轴的位置
axs_A2.set_xlabel('数量', fontsize=20, labelpad=30)
axs_A2.xaxis.set_label_coords(0.5, -0.1)  # (x, y) 坐标分别控制 x 轴和 y 轴的位置
# 添加y轴标签
axs_A1.set_ylabel('大洲域名', fontsize=20, labelpad=90)
axs_A1.yaxis.set_label_coords(-0.25, 0.48) 
axs_A2.set_ylabel('领域域名', fontsize=20, labelpad=90)
axs_A2.yaxis.set_label_coords(-0.18, 0.48)  

fig.subplots_adjust(wspace=0.26, hspace=0.28)

fig.text(0.024, 0.925, 'a', fontsize=24, va='top', fontweight='bold')
fig.text(0.482, 0.925, 'b', fontsize=24, va='top', fontweight='bold')
# Out:
# Text(0.482, 0.925, 'b')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, axs = plt.subplots(2, 1, figsize=(10, 8))  # 调整图形大小

axs[0, 0]
axs[1, 0]




member = [u'Asia', u'Africa', u'North America', u'South America'
          ,u'Antarctica',u'Europe',u'Oceania']
#亚洲，非洲，北美，南美，南极洲，欧洲，大洋洲
domain_1 = [346, 562, 148623, 332, 8903, 311, 37]  
domain_2 = [338, 118, 42599, 143, 106, 287, 38] 
domain_3 = [295, 86, 33319,  178, 78, 33, 49]  
domain_4 = [199, 102, 21239,  202, 75, 33, 36]
domain_5 = [94, 171, 17483, 273, 67, 33, 122]


# 自定义标签
labels_1 = ['straitstimes.com', 'aljazeera.com', 'reuters.com', 'bbc.co','vice.com','ibtimes.co.uk','sbs.com.au']
labels_2 = ['alibaba.com', 'mg.co.za', 'cnbc.com', 'thefader.com','iceheadshop.org','telegraph.co.uk','skyscanner.com.au']
labels_3 = ['yatra.com', 'allafrica.com', 'nytimes.com', 'infonegocios.com.ar','budapest.climatemps.com','dailymail.co.uk','news.com.au']
labels_4 = ['hindustantimes.com', 'naij.com', 'cnn.com', 'eltiempo.com','globalvoices.org','irishtimes.com','9news.com.au']
labels_5 = ['japantimes.co.jp', 'theafricareport.com', 'thehill.com', 'larepublica.pe','winnipeg.climatemps.com','sputniknews.com','nzherald.co.nz']
bar_width = 0.15  # 设置分组条形的宽度

# 绘图
bars_1 = plt.barh(np.arange(7), domain_1,  height=bar_width, align='center', color='#CD5257', alpha=0.7)
bars_2 = plt.barh(np.arange(7) + bar_width, domain_2,  color='#F2BA2F', alpha=0.7, height=bar_width)
bars_3 = plt.barh(np.arange(7) + bar_width * 2, domain_3, color='#2673EF', alpha=0.7, height=bar_width)
bars_4 = plt.barh(np.arange(7) + bar_width * 3, domain_4,  color='#95BE54', alpha=0.7, height=bar_width)
bars_5 = plt.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
# 添加X轴标签
plt.xlabel('Count',fontdict=fontdict3)
# 添加y轴标签
plt.ylabel('Continent Domain',fontdict=fontdict3)
# 添加标题
plt.title('Typical domain name distribution by continent',fontdict=fontdict1)
# 添加刻度标签
plt.yticks(np.arange(7) + bar_width*2, member,fontdict=fontdict1)
plt.xscale('log')

# 设置 x 轴范围
plt.xlim(1, 780000)  # 将上限设置为 160000

# 在条形的顶端加上自定义标签
fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
for bars, labels in zip([bars_1, bars_2, bars_3,bars_4,bars_5], [labels_1, labels_2, labels_3,labels_4,labels_5]):
    for bar, label in zip(bars, labels):
        width = bar.get_width()
        plt.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontdict=fontdict2)

# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3 import matplotlib as mpl
#       5 fig, axs = plt.subplots(2, 1, figsize=(10, 8))  # 调整图形大小
# ----> 7 axs[0, 0]
#       8 axs[1, 0]
#      13 member = [u'Asia', u'Africa', u'North America', u'South America'
#      14           ,u'Antarctica',u'Europe',u'Oceania']
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.figure(figsize=(10, 8))  # 调整图形大小
member = [u'Culture', u'Sport', u'Military', u'Policy'
          ,u'Family',u'Economiscs',u'Medicine']
#文化 体育 战争 政策 家庭 经济 医疗
domain_1 = [33319, 159, 84, 17483, 8294, 42599, 120]  
domain_2 = [199, 62, 48, 4072, 178, 28, 49] 
domain_3 = [551, 56, 105,  2959, 80, 58, 1249]  
domain_4 = [483, 53, 61,  21239, 42, 5770, 145]
domain_5 = [446, 46, 274, 123, 41, 301, 45]


# 自定义标签
labels_1 = ['nytimes.com', 'si.com', 'military.com', 'thehill.com','people.com','cnbc.com','ncbi.nlm.nih.gov']
labels_2 = ['hindustantimes.com', 'espn.com', 'globalsecurity.org', 'politico.com','betterbatt.com.au','bloomberg.com','medgadget.com']
labels_3 = ['theguardian.com', 'nhl.com', 'defense.gov', 'foxnews.com','absolutelypsychic.com','wsj.com','canadiandiscountdrugs.net']
labels_4 = ['washingtonpost.com', 'socceroos.com.au', 'nationmultimedia.com', 'cnn.com','dignitymemorial.com','businessinsider.com','health.economictimes.indiatimes.com']
labels_5 = ['newyorker.com', 'teamusa.org', 'defenseone.com', 'nbcnews.com','justgiving.com','forbes.com','pubfacts.com']
bar_width = 0.15  # 设置分组条形的宽度

# 绘图
bars_1 = plt.barh(np.arange(7), domain_1,  height=bar_width, align='center', color='#CD5257', alpha=0.7)
bars_2 = plt.barh(np.arange(7) + bar_width, domain_2,  color='#F2BA2F', alpha=0.7, height=bar_width)
bars_3 = plt.barh(np.arange(7) + bar_width * 2, domain_3, color='#2673EF', alpha=0.7, height=bar_width)
bars_4 = plt.barh(np.arange(7) + bar_width * 3, domain_4,  color='#95BE54', alpha=0.7, height=bar_width)
bars_5 = plt.barh(np.arange(7) + bar_width * 4, domain_5,  color='#F1DEBD', alpha=0.7, height=bar_width)


fontdict1 = {'family': 'Times New Roman', 'fontsize': 15}
fontdict3 = {'family': 'Times New Roman', 'fontsize': 14}
# 添加X轴标签
plt.xlabel('Count',fontdict=fontdict3)
# 添加y轴标签
plt.ylabel('Topic Domain',fontdict=fontdict3)
# 添加标题
plt.title('Typical domain name distribution by topic',fontdict=fontdict1)
# 添加刻度标签
plt.yticks(np.arange(7) + bar_width*2, member,fontdict=fontdict1)
plt.xscale('log')

# 设置 x 轴范围
plt.xlim(1, 180000)  # 将上限设置为 160000

# 在条形的顶端加上自定义标签
fontdict2 = {'family': 'Times New Roman', 'fontsize': 9}
for bars, labels in zip([bars_1, bars_2, bars_3,bars_4,bars_5], [labels_1, labels_2, labels_3,labels_4,labels_5]):
    for bar, label in zip(bars, labels):
        width = bar.get_width()
        plt.text(width + 4.5, bar.get_y() + bar.get_height()/2, label, ha='left', va='center', fontdict=fontdict2)

# plt.legend()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
